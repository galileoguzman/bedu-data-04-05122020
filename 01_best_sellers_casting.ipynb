# %%
# Importing data
import pandas as pd

FILENAME = 'datasets/best_sellers.csv'

# Reading a CSV file using pandas
df = pd.read_csv(FILENAME)

# %%
df.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# 0  Little, Brown                  THE HOST  5b4aa4ead3089013507db18c
# 1   St. Martin's  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2         Putnam                 THE FRONT  5b4aa4ead3089013507db18e
# 3      Doubleday                     SNUFF  5b4aa4ead3089013507db18f
# 4         Putnam              PHANTOM PREY  5b4aa4ead3089013507db191
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
# 3         2008-05-24 00:00:00              1212883200000              5
# 4         2008-05-24 00:00:00              1212883200000              7
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 4                         4                        3               26.95

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# amazon_product_url              object
# author                          object
# description                     object
# publisher                       object
# title                           object
# oid                             object
# bestsellers_date.numberLong     object
# published_date.numberLong        int64
# rank.numberInt                  object
# rank_last_week.numberInt         int64
# weeks_on_list.numberInt          int64
# price.numberDouble             float64
# dtype: object

# %%
numero = '100'
print(type(numero))
# Out:
# <class 'str'>

# %%
numero = int(numero)
print(type(numero))
# Out:
# <class 'int'>

# %%
casting_dict = {
    'bestsellers_date.numberLong': 'datetime64[ns]',
    'published_date.numberLong': 'datetime64[ns]'
}

df2 = df.astype(casting_dict)
df2.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# 0  Little, Brown                  THE HOST  5b4aa4ead3089013507db18c
# 1   St. Martin's  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2         Putnam                 THE FRONT  5b4aa4ead3089013507db18e
# 3      Doubleday                     SNUFF  5b4aa4ead3089013507db18f
# 4         Putnam              PHANTOM PREY  5b4aa4ead3089013507db191
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0                  2008-05-24 1970-01-01 00:20:12.883200              2
# 1                  2008-05-24 1970-01-01 00:20:12.883200              3
# 2                  2008-05-24 1970-01-01 00:20:12.883200              4
# 3                  2008-05-24 1970-01-01 00:20:12.883200              5
# 4                  2008-05-24 1970-01-01 00:20:12.883200              7
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 4                         4                        3               26.95

# %%
df2.dtypes
# Out:
# Unnamed: 0                              int64
# amazon_product_url                     object
# author                                 object
# description                            object
# publisher                              object
# title                                  object
# oid                                    object
# bestsellers_date.numberLong    datetime64[ns]
# published_date.numberLong      datetime64[ns]
# rank.numberInt                         object
# rank_last_week.numberInt                int64
# weeks_on_list.numberInt                 int64
# price.numberDouble                    float64
# dtype: object

# %%
# Panda configuration
pd.to_datetime(df['published_date.numberLong'], unit='ms')
# Out:
# 0      2008-06-08
# 1      2008-06-08
# 2      2008-06-08
# 3      2008-06-08
# 4      2008-06-08
#           ...
# 2261   2013-05-05
# 2262   2013-05-05
# 2263   2013-05-05
# 2264   2013-05-05
# 2265   2013-05-05
# Name: published_date.numberLong, Length: 2266, dtype: datetime64[ns]

# %%
df['rank.numberInt'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-179e35ea2d8a> in <module>
# ----> 1 df['rank.numberInt'].astype(int)
#
# ~/Desktop/bedu_data_04_05122020/.venv/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/Desktop/bedu_data_04_05122020/.venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ~/Desktop/bedu_data_04_05122020/.venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/Desktop/bedu_data_04_05122020/.venv/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/Desktop/bedu_data_04_05122020/.venv/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     972         # work around NumPy brokenness, #1987
#     973         if np.issubdtype(dtype.type, np.integer):
# --> 974             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     975
#     976         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'No Rank'

# %%
pd.to_numeric(df['rank.numberInt'], errors='coerce')
# Out:
# 0        2.0
# 1        3.0
# 2        4.0
# 3        5.0
# 4        7.0
#         ...
# 2261     8.0
# 2262     9.0
# 2263    11.0
# 2264    13.0
# 2265    14.0
# Name: rank.numberInt, Length: 2266, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# 0  Little, Brown                  THE HOST  5b4aa4ead3089013507db18c
# 1   St. Martin's  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2         Putnam                 THE FRONT  5b4aa4ead3089013507db18e
# 3      Doubleday                     SNUFF  5b4aa4ead3089013507db18f
# 4         Putnam              PHANTOM PREY  5b4aa4ead3089013507db191
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
# 3         2008-05-24 00:00:00              1212883200000              5
# 4         2008-05-24 00:00:00              1212883200000              7
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 4                         4                        3               26.95
